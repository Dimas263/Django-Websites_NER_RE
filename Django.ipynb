# %% [markdown]
# # **Django Website NER dan RE**

# %% [markdown]
# **Python Libraries**

# %%
! pip install django
! pip install pandas==0.23.4
! pip install pickle5
! pip install termcolor==1.1.0
! pip install six==1.16.0
! pip install tensorflow==1.13.1
! pip install keras==2.3.1
! pip install git+https://www.github.com/keras-team/keras-contrib.git
! pip install numpy==1.16.2
! pip install matplotlib==2.2.4
! pip install scikit-learn==0.24.2
! pip install 'h5py==2.10.0' --force-reinstall
! pip install numpy==1.16.2 --force-reinstall

# %% [markdown]
# **Connect Drive Storage**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ! django-admin startproject WEBSITE_NER_RE

# %%
# %cd /content/drive/MyDrive/Rearch_Dimas/WEBSITE_NER_RE/
# Out:
# /content/drive/.shortcut-targets-by-id/1WEsdtCJVextem2weRJgfU7VjmEIVOatH/WEBSITE_NER_RE

# %% [markdown]
# # **Domain Website**

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://o4zjtfg1f6g-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %% [markdown]
# # **Run Django Website**

# %% [markdown]
# ### **Restart cell setelah prediksi di web django, model graph vector hanya memprediksi sekali**
#
# jika ingin memprediksi lagi, jalankan ulang cell ini,
# proses prediksi memakan waktu sekitar 4-5 menit

# %%
! python /content/drive/MyDrive/Rearch_Dimas/WEBSITE_NER_RE/manage.py runserver --nothreading --noreload
# Out:
# Performing system checks...
#
# /usr/local/lib/python3.7/dist-packages/scipy/__init__.py:149: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.16.2
#   UserWarning)
# Using TensorFlow backend.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Keras NER model loading.......
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2022-07-18 07:33:05.330216: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-07-18 07:33:05.333722: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# ...
